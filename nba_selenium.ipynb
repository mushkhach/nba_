# %%
from selenium import webdriver
browser = webdriver.Chrome()
url = "http://www.nba.com/players"
browser.get(url)

# %%
listt=[]
for i in browser.find_elements_by_xpath('//*[@id="player-left-block"]/a'):
    listt.append(i.get_attribute('href'))

# %%
y

# %%
x
# Out:
# u"A\nAbrines, Alex\nOKC\nAcy, Quincy\nBKN\nAdams, Steven\nOKC\nAdebayo, Bam\nMIA\nAjinca, Alexis\nNOP\nAldrich, Cole\nMIN\nAldridge, LaMarcus\nSAS\nAllen, Jarrett\nBKN\nAllen, Kadeem\nBOS\nAllen, Lavoy\nIND\nAllen, Tony\nMEM\nAminu, Al-Farouq\nPOR\nAnderson, Alan\nLAC\nAnderson, Justin\nPHI\nAnderson, Kyle\nSAS\nAnderson, Ryan\nHOU\nAnigbogu, Ike\nIND\nAntetokounmpo, Giannis\nMIL\nAnthony, Carmelo\nNYK\nAnthony, Joel\nSAS\nAnunoby, OG\nTOR\nAriza, Trevor\nHOU\nArthur, Darrell\nDEN\nAsik, Omer\nNOP\nAugustin, D.J.\nORL\nB\nBabbitt, Luke\nMIA\nBacon, Dwayne\nCHA\nBaker, Ron\nNYK\nBaldwin IV, Wade\nMEM\nBall, Lonzo\nLAL\nBarea, J.J.\nDAL\nBarnes, Harrison\nDAL\nBarnes, Matt\nGSW\nBarton, Will\nDEN\nBass, Brandon\nLAC\nBatum, Nicolas\nCHA\nBayless, Jerryd\nPHI\nBazemore, Kent\nATL\nBeal, Bradley\nWAS\nBeasley, Malik\nDEN\nBeasley, Michael\nMIL\nBelinelli, Marco\nATL\nBell, Jordan\nGSW\nBembry, DeAndre'\nATL\nBender, Dragan\nPHX\nBertans, Davis\nSAS\nBeverley, Patrick\nLAC\nBird, Jabari\n
# ...

# %%
z=re.findall('\n([A-Z][a-z]*[,]\s*[A-Z]*[a-z]*)',x)

# %%
print(z)
# Out:
# [u'Abrines, Alex', u'Acy, Quincy', u'Adams, Steven', u'Adebayo, Bam', u'Ajinca, Alexis', u'Aldrich, Cole', u'Aldridge, La', u'Allen, Jarrett', u'Allen, Kadeem', u'Allen, Lavoy', u'Allen, Tony', u'Aminu, Al', u'Anderson, Alan', u'Anderson, Justin', u'Anderson, Kyle', u'Anderson, Ryan', u'Anigbogu, Ike', u'Antetokounmpo, Giannis', u'Anthony, Carmelo', u'Anthony, Joel', u'Anunoby, OG', u'Ariza, Trevor', u'Arthur, Darrell', u'Asik, Omer', u'Augustin, D', u'Babbitt, Luke', u'Bacon, Dwayne', u'Baker, Ron', u'Ball, Lonzo', u'Barea, J', u'Barnes, Harrison', u'Barnes, Matt', u'Barton, Will', u'Bass, Brandon', u'Batum, Nicolas', u'Bayless, Jerryd', u'Bazemore, Kent', u'Beal, Bradley', u'Beasley, Malik', u'Beasley, Michael', u'Belinelli, Marco', u'Bell, Jordan', u'Bembry, De', u'Bender, Dragan', u'Bertans, Davis', u'Beverley, Patrick', u'Bird, Jabari', u'Biyombo, Bismack', u'Bjelica, Nemanja', u'Bledsoe, Eric', u'Blossomgame, Jaron', u'Bogdanovic, Bogdan', u'Bogdanovic, Bojan', u'Bolden, Jonah'
# ...

# %%
z[0]
# Out:
# u'Abrines, Alex'

# %%
z
# Out:
# [u'Abrines, Alex',
#  u'Acy, Quincy',
#  u'Adams, Steven',
#  u'Adebayo, Bam',
#  u'Ajinca, Alexis',
#  u'Aldrich, Cole',
#  u'Aldridge, La',
#  u'Allen, Jarrett',
#  u'Allen, Kadeem',
#  u'Allen, Lavoy',
#  u'Allen, Tony',
#  u'Aminu, Al',
#  u'Anderson, Alan',
#  u'Anderson, Justin',
#  u'Anderson, Kyle',
#  u'Anderson, Ryan',
#  u'Anigbogu, Ike',
#  u'Antetokounmpo, Giannis',
#  u'Anthony, Carmelo',
#  u'Anthony, Joel',
#  u'Anunoby, OG',
#  u'Ariza, Trevor',
#  u'Arthur, Darrell',
#  u'Asik, Omer',
#  u'Augustin, D',
#  u'Babbitt, Luke',
#  u'Bacon, Dwayne',
#  u'Baker, Ron',
#  u'Ball, Lonzo',
#  u'Barea, J',
#  u'Barnes, Harrison',
#  u'Barnes, Matt',
#  u'Barton, Will',
#  u'Bass, Brandon',
#  u'Batum, Nicolas',
#  u'Bayless, Jerryd',
#  u'Bazemore, Kent',
#  u'Beal, Bradley',
#  u'Beasley, Malik',
#  u'Beasley, Michael',
#  u'Belinelli, Marco',
#  u'Bell, Jordan',
#  u'Bembry, De',
#  u'Bender, Dragan',
#  u'Bertans, Davis',
#  u'Beverley, Patrick',
#  u'Bird, Jabari',
# ...

# %%
z[0::2]
# Out:
# [u'Abrines, Alex',
#  u'Acy, Quincy',
#  u'Adams, Steven',
#  u'Adebayo, Bam',
#  u'Ajinca, Alexis',
#  u'Aldrich, Cole',
#  u'Aldridge, LaMarcus',
#  u'Allen, Jarrett',
#  u'Allen, Kadeem',
#  u'Allen, Lavoy',
#  u'Allen, Tony',
#  u'Aminu, Al-Farouq',
#  u'Anderson, Alan',
#  u'Anderson, Justin',
#  u'Anderson, Kyle',
#  u'Anderson, Ryan',
#  u'Anigbogu, Ike',
#  u'Antetokounmpo, Giannis',
#  u'Anthony, Carmelo',
#  u'Anthony, Joel',
#  u'Anunoby, OG',
#  u'Ariza, Trevor',
#  u'Arthur, Darrell',
#  u'Asik, Omer',
#  u'Augustin, D.J.',
#  u'B',
#  u'MIA',
#  u'CHA',
#  u'NYK',
#  u'MEM',
#  u'LAL',
#  u'DAL',
#  u'DAL',
#  u'GSW',
#  u'DEN',
#  u'LAC',
#  u'CHA',
#  u'PHI',
#  u'ATL',
#  u'WAS',
#  u'DEN',
#  u'MIL',
#  u'ATL',
#  u'GSW',
#  u'ATL',
#  u'PHX',
#  u'SAS',
#  u'LAC',
#  u'BOS',
#  u'ORL',
#  u'MIN',
#  u'PHX',
#  u'SAS',
#  u'SAC',
#  u'IND',
#  u'PHI',
#  u'UTA',
#  u'PHX',
#  u'BKN',
#  u'DET',
#  u'UTA',
#  u'LAL',
#  u'MIL',
#  u'IND',
#  u'MEM',
#  u'HOU',
# ...

# %%
for count, i in enumerate(z):
    if count % 2 == 1:
        l.append(i)

# %%
i
# Out:
# u'LAL'

# %%
zip(z,listt)
# Out:
# [(u'Abrines, Alex', u'http://www.nba.com/players/alex/abrines/203518'),
#  (u'Acy, Quincy', u'http://www.nba.com/players/quincy/acy/203112'),
#  (u'Adams, Steven', u'http://www.nba.com/players/steven/adams/203500'),
#  (u'Adebayo, Bam', u'http://www.nba.com/players/bam/adebayo/1628389'),
#  (u'Ajinca, Alexis', u'http://www.nba.com/players/alexis/ajinca/201582'),
#  (u'Aldrich, Cole', u'http://www.nba.com/players/cole/aldrich/202332'),
#  (u'Aldridge, La', u'http://www.nba.com/players/lamarcus/aldridge/200746'),
#  (u'Allen, Jarrett', u'http://www.nba.com/players/jarrett/allen/1628386'),
#  (u'Allen, Kadeem', u'http://www.nba.com/players/kadeem/allen/1628443'),
#  (u'Allen, Lavoy', u'http://www.nba.com/players/lavoy/allen/202730'),
#  (u'Allen, Tony', u'http://www.nba.com/players/tony/allen/2754'),
#  (u'Aminu, Al', u'http://www.nba.com/players/al-farouq/aminu/202329'),
#  (u'Anderson, Alan', u'http://www.nba.com/players/alan/anderson/101187'),
# ...
